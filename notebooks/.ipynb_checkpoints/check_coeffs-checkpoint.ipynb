# %%
import pandas as pd, os
from synthicity.utils import misc
coeff_store_path = os.path.join(misc.data_dir(),'coeffs.h5')
coeff_store = pd.HDFStore(coeff_store_path)

# %%
coeff_store.coeffs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 22
# Data columns (total 94 columns):
# (hh_location_1, coeffs)        20  non-null values
# (hh_location_1, fnames)        20  non-null values
# (hh_location_2, coeffs)        21  non-null values
# (hh_location_2, fnames)        21  non-null values
# (hh_location_3, coeffs)        22  non-null values
# (hh_location_3, fnames)        22  non-null values
# (hh_location_4, coeffs)        18  non-null values
# (hh_location_4, fnames)        18  non-null values
# (hh_location_5, coeffs)        21  non-null values
# (hh_location_5, fnames)        21  non-null values
# (emp_location_11, coeffs)      23  non-null values
# (emp_location_11, fnames)      23  non-null values
# (emp_location_21, coeffs)      23  non-null values
# (emp_location_21, fnames)      23  non-null values
# (emp_location_22, coeffs)      23  non-null values
# (emp_location_22, fnames)      23  non-null values
# ...

# %%
print coeff_store.coeffs[('hh_location_1', 'fnames')]
print coeff_store.coeffs[('hh_location_1', 'coeffs')]
# Out:
# 0                              ln_dist_rail
# 1                    ln_avg_unit_price_zone
# 2                        median_age_of_head
# 3                median_yearbuilt_post_1990
# 4     percent_hh_with_child_x_hh_with_child
# 5                 percent_renter_hh_in_zone
# 6                                  townhome
# 7                               multifamily
# 8                         jobs_within_45min
# 9                                county8001
# 10                               county8005
# 11                               county8013
# 12                               county8014
# 13                               county8019
# 14                               county8031
# 15                               county8035
# 16                               county8039
# 17                               county8047
# 18                               county8059
# 19                               county8123
# 20                                      NaN
# ...

# %%
print coeff_store.coeffs[('emp_location_11', 'fnames')]
print coeff_store.coeffs[('emp_location_11', 'coeffs')]
# Out:
# 0                         ln_jobs_within_30min
# 1                ln_avg_nonres_unit_price_zone
# 2                            median_year_built
# 3             ln_residential_unit_density_zone
# 4                          ln_pop_within_20min
# 5                                   nonres_far
# 6                                       office
# 7                         retail_or_restaurant
# 8                          industrial_building
# 9     employees_x_ln_non_residential_sqft_zone
# 10                                ln_dist_rail
# 11                            rail_within_mile
# 12                                  county8001
# 13                                  county8005
# 14                                  county8013
# 15                                  county8014
# 16                                  county8019
# 17                                  county8031
# 18                                  county8035
# 19                                  county8039
# ...
