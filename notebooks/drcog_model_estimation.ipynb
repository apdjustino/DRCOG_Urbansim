# %% [markdown]
# # DRCOG Model Estimation

# %%
import numpy as np, pandas as pd, os
from synthicity.utils import misc
from drcog.models import regression_model_estimation, choice_model_estimation, dataset
dset = dataset.DRCOGDataset(os.path.join(misc.data_dir(),'drcog.h5'))
np.random.seed(1)

##Variable Library
from drcog.variables import variable_library
variable_library.calculate_variables(dset)

establishments = dset.establishments
households = dset.households
households_for_estimation = dset.households_for_estimation
buildings = dset.buildings
# Out:
# Fetching parcels
# Fetching modify_table
# Fetching buildings
# Fetching establishments
# Fetching modify_table
# Fetching modify_table
# Fetching households_for_estimation
# Fetching modify_table
# Fetching households
# Fetching modify_table
# Fetching zones
# Fetching modify_table
# Fetching travel_data
# Fetching modify_table

# %% [markdown]
# ## Household Location Choice Model Estimation

# %%
##Specify independent variables for each segment here.  Each variable must be represented in the variable library.  
##There must be a set of independent variables corresponding to each segment.  
ind_vars1=['ln_dist_rail','ln_avg_unit_price_zone','median_age_of_head','median_yearbuilt_post_1990','percent_hh_with_child_x_hh_with_child','percent_renter_hh_in_zone',
           'townhome','multifamily','jobs_within_45min']
ind_vars2=['ln_dist_rail','income5xlt_x_avg_unit_price_zone','median_age_of_head','median_yearbuilt_post_1990','median_yearbuilt_pre_1950','percent_hh_with_child_x_hh_with_child','percent_renter_hh_in_zone',
           'multifamily','ln_income_x_average_resunit_size','wkrs_hhs_x_ln_jobs_within_30min']
ind_vars3=['ln_dist_rail','income5xlt_x_avg_unit_price_zone','median_age_of_head','mean_income','median_yearbuilt_post_1990','median_yearbuilt_pre_1950','ln_income_x_average_resunit_size','percent_renter_hh_in_zone',
           'cherry_creek_school_district','percent_younghead_x_younghead','ln_jobs_within_30min']
ind_vars4=['ln_dist_rail','percent_hh_with_child_x_hh_with_child','percent_renter_hh_in_zone',
           'multifamily','percent_younghead_x_younghead','ln_emp_sector3_within_20min','allpurpose_agglosum_floor']
ind_vars5=['income5xlt_x_avg_unit_price_zone','median_age_of_head','mean_income','median_yearbuilt_post_1990','percent_hh_with_child_x_hh_with_child','percent_renter_hh_in_zone',
           'townhome','multifamily','percent_younghead_x_younghead','wkrs_hhs_x_ln_jobs_within_30min']

##Estimate
choice_model_estimation.estimate(dset,[ind_vars1,ind_vars2,ind_vars3,ind_vars4,ind_vars5],depvar = 'building_id',alternatives=dset.buildings,
                         SAMPLE_SIZE=100,max_segment_size = 1200,estimation_table = 'households_for_estimation',
                         output_names=("drcog-coeff-hlcm-%s.csv","DRCOG HOUSEHOLD LOCATION CHOICE MODELS (%s)","hh_location_%s","household_building_ids"),
                         agents_groupby= ['income_3_tenure',])
# Out:
# Estimating parameters for segment = 1, size = 232
# Null Log-liklihood: -1068.399483
# Log-liklihood at convergence: -961.410694
# Log-liklihood ratio: 0.100139
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# | ln dist rail |       -0.120 |        0.050 |       -2.290 | *            |
# +--------------+--------------+--------------+--------------+--------------+
# |  ln avg unit |            0 |        0.070 |        0.040 |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   median age |        0.060 |        0.010 |        5.650 | ***          |
# |      of head |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       median |        0.390 |        0.180 |        2.210 | *            |
# |    yearbuilt |              |              |              |              |
# |    post 1990 |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   percent hh |        0.020 |            0 |        4.740 | ***          |
# | with child x |              |              |              |              |
# |      hh with |              |              |              |              |
# |        child |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |        0.020 |        0.010 |        3.560 | ***          |
# | renter hh in |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |     townhome |        1.230 |        0.240 |        5.210 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |  multifamily |        2.010 |        0.170 |       12.210 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |  jobs within |            0 |            0 |        0.230 |              |
# |        45min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 2, size = 462
# Null Log-liklihood: -2127.588626
# Log-liklihood at convergence: -2060.582276
# Log-liklihood ratio: 0.031494
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# | ln dist rail |       -0.160 |        0.040 |       -4.350 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# | income5xlt x |       -1.310 |        0.360 |       -3.600 | ***          |
# |     avg unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   median age |        0.010 |        0.010 |        1.430 | .            |
# |      of head |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       median |        0.600 |        0.120 |        4.880 | ***          |
# |    yearbuilt |              |              |              |              |
# |    post 1990 |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       median |        0.390 |        0.160 |        2.370 | **           |
# |    yearbuilt |              |              |              |              |
# |     pre 1950 |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   percent hh |        0.010 |            0 |        2.180 | *            |
# | with child x |              |              |              |              |
# |      hh with |              |              |              |              |
# |        child |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |            0 |            0 |        0.430 |              |
# | renter hh in |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  multifamily |        0.930 |        0.170 |        5.630 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |  ln income x |            0 |            0 |        4.830 | ***          |
# |      average |              |              |              |              |
# | resunit size |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   wkrs hhs x |        0.120 |        0.010 |       10.020 | ***          |
# |      ln jobs |              |              |              |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 3, size = 268
# Null Log-liklihood: -1234.185610
# Log-liklihood at convergence: -1157.142260
# Log-liklihood ratio: 0.062424
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# | ln dist rail |       -0.210 |        0.040 |       -4.830 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# | income5xlt x |       -0.010 |        0.630 |       -0.020 |              |
# |     avg unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   median age |       -0.010 |        0.020 |       -0.360 |              |
# |      of head |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  mean income |            0 |            0 |        2.960 | **           |
# +--------------+--------------+--------------+--------------+--------------+
# |       median |        0.170 |        0.170 |        0.990 |              |
# |    yearbuilt |              |              |              |              |
# |    post 1990 |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       median |        0.120 |        0.210 |        0.600 |              |
# |    yearbuilt |              |              |              |              |
# |     pre 1950 |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  ln income x |            0 |            0 |        4.940 | ***          |
# |      average |              |              |              |              |
# | resunit size |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |        0.020 |        0.010 |        2.330 | **           |
# | renter hh in |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# | cherry creek |        0.100 |        0.200 |        0.500 |              |
# |       school |              |              |              |              |
# |     district |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |        0.080 |        0.020 |        4.210 | ***          |
# |  younghead x |              |              |              |              |
# |    younghead |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      ln jobs |        0.160 |        0.080 |        1.910 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 4, size = 263
# Null Log-liklihood: -1211.159759
# Log-liklihood at convergence: -780.092679
# Log-liklihood ratio: 0.355913
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# | ln dist rail |       -0.130 |        0.040 |       -3.310 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |   percent hh |        0.060 |            0 |       13.990 | ***          |
# | with child x |              |              |              |              |
# |      hh with |              |              |              |              |
# |        child |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |        0.040 |        0.010 |        6.350 | ***          |
# | renter hh in |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  multifamily |            3 |        0.150 |       20.600 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |        0.030 |        0.010 |        4.070 | ***          |
# |  younghead x |              |              |              |              |
# |    younghead |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |       -0.240 |        0.090 |       -2.700 | **           |
# |      sector3 |              |              |              |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   allpurpose |        0.190 |        0.070 |        2.730 | **           |
# |     agglosum |              |              |              |              |
# |        floor |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 5, size = 217
# Null Log-liklihood: -999.321930
# Log-liklihood at convergence: -822.638270
# Log-liklihood ratio: 0.176804
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# | income5xlt x |       -0.430 |        0.280 |       -1.520 | .            |
# |     avg unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   median age |        0.010 |        0.010 |        1.440 | .            |
# |      of head |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  mean income |            0 |            0 |        4.220 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       median |        0.860 |        0.170 |        5.030 | ***          |
# |    yearbuilt |              |              |              |              |
# |    post 1990 |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   percent hh |        0.010 |            0 |        1.940 | *            |
# | with child x |              |              |              |              |
# |      hh with |              |              |              |              |
# |        child |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |        0.050 |        0.010 |        8.810 | ***          |
# | renter hh in |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |     townhome |        0.490 |        0.280 |        1.710 | *            |
# +--------------+--------------+--------------+--------------+--------------+
# |  multifamily |        2.430 |        0.170 |       14.020 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |      percent |       -0.010 |        0.010 |       -0.620 |              |
# |  younghead x |              |              |              |              |
# |    younghead |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   wkrs hhs x |        0.190 |        0.020 |       11.450 | ***          |
# |      ln jobs |              |              |              |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+

# %% [markdown]
# ## Establishment Location Choice Model

# %%
##Specify independent variables for each segment here.  Each variable must be represented in the variable library.  
##There must be a set of independent variables corresponding to each segment.  
ind_vars11=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_dist_rail','rail_within_mile']
ind_vars21=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars22=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars23=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars31=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars32=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars33=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars42=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector2_within_15min','rail_within_mile']
ind_vars44=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector5_within_15min','rail_within_mile']
ind_vars45=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector5_within_15min','rail_within_mile']
ind_vars48=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars49=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector3_within_15min','rail_within_mile']
ind_vars51=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars52=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars53=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars54=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars55=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars56=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars61=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector1_within_15min','rail_within_mile']
ind_vars62=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars71=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector2_within_15min','rail_within_mile']
ind_vars81=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars92=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector6_within_15min','rail_within_mile']
ind_vars7211=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector5_within_15min','rail_within_mile']
ind_vars7221=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector4_within_15min','rail_within_mile']
ind_vars7222=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector4_within_15min','rail_within_mile']
ind_vars7223=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector5_within_15min','rail_within_mile']
ind_vars7224=['ln_jobs_within_30min','ln_avg_nonres_unit_price_zone','median_year_built','ln_residential_unit_density_zone','ln_pop_within_20min','nonres_far',
           'office','retail_or_restaurant','industrial_building','employees_x_ln_non_residential_sqft_zone','ln_emp_sector4_within_15min','rail_within_mile']

##Apply filters
dset.d['establishments_for_estimation'] = establishments[(establishments.building_id>0)*(establishments.home_based_status==0)*(establishments.nonres_sqft>0)]

##Estimate
choice_model_estimation.estimate(dset,[ind_vars11,ind_vars21,ind_vars22,ind_vars23,ind_vars31,ind_vars32,ind_vars33,ind_vars42,ind_vars44,ind_vars45,ind_vars48,ind_vars49,ind_vars51,ind_vars52,ind_vars53,ind_vars54,ind_vars55,ind_vars56,ind_vars61,ind_vars62,ind_vars71,ind_vars81,ind_vars92,ind_vars7211,ind_vars7221,ind_vars7222,ind_vars7223,ind_vars7224],depvar = 'building_id',alternatives=dset.buildings,
                         SAMPLE_SIZE=100,max_segment_size = 2400,estimation_table = 'establishments_for_estimation',
                         output_names=("drcog-coeff-elcm-%s.csv","DRCOG EMPLOYMENT LOCATION CHOICE MODELS (%s)","emp_location_%s","establishment_building_ids"),
                         agents_groupby= ['sector_id_retail_agg',])
# Out:
# Estimating parameters for segment = 11, size = 181
# Null Log-liklihood: -833.535804
# Log-liklihood at convergence: -435.036413
# Log-liklihood ratio: 0.478083
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |       -0.320 |        0.150 |       -2.080 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.100 |        0.080 |        1.240 |              |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        5.470 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.780 |        0.130 |       -5.930 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.220 |        0.150 |        1.400 | .            |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.480 |        0.050 |       10.590 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.810 |        0.270 |        3.030 | **           |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.080 |        0.270 |        0.290 |              |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |       -0.200 |        0.270 |       -0.750 |              |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |        5.730 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# | ln dist rail |        0.180 |        0.110 |        1.550 | .            |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |       -0.450 |        0.450 |       -1.010 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 21, size = 698
# Null Log-liklihood: -3214.408790
# Log-liklihood at convergence: -511.428941
# Log-liklihood ratio: 0.840895
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |       -0.040 |        0.270 |       -0.160 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.310 |        0.060 |        5.650 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        3.590 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.250 |        0.080 |       -3.140 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.090 |        0.290 |        0.310 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.650 |        0.050 |       13.520 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        2.550 |        0.220 |       11.860 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |       -0.590 |        0.330 |       -1.820 | *            |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.980 |        0.230 |        4.350 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |        1.300 | .            |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |       -0.150 |        0.140 |       -1.070 |              |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        1.150 |        0.170 |        6.780 | ***          |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 22, size = 201
# Null Log-liklihood: -925.639207
# Log-liklihood at convergence: -316.451159
# Log-liklihood ratio: 0.658127
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.460 |        0.250 |        1.880 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.060 |        0.110 |        0.570 |              |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.010 |            0 |       19.050 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.560 |        0.130 |       -4.410 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.550 |        0.330 |       -1.680 | *            |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.580 |        0.060 |        9.110 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        2.220 |        0.280 |        8.050 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.260 |        0.340 |        0.780 |              |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.950 |        0.280 |        3.420 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       -1.840 | *            |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |       -0.010 |        0.170 |       -0.050 |              |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |       -0.310 |        0.270 |       -1.160 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 23, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -3810.137002
# Log-liklihood ratio: 0.655266
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.430 |        0.090 |        4.640 | ***          |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.060 |        0.030 |        2.370 | **           |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |       22.860 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.260 |        0.030 |       -7.950 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.110 |        0.100 |       -1.020 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.520 |        0.020 |       25.890 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        2.190 |        0.090 |       23.720 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        1.080 |        0.100 |       11.230 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        2.060 |        0.090 |       23.540 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       45.260 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |       -0.100 |        0.050 |       -1.900 | *            |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.090 |        0.060 |        1.400 | .            |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 31, size = 589
# Null Log-liklihood: -2712.445240
# Log-liklihood at convergence: -839.709114
# Log-liklihood ratio: 0.690424
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |       -0.470 |        0.230 |       -2.090 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.100 |        0.070 |        1.480 | .            |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        1.430 | .            |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.170 |        0.070 |       -2.280 | *            |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.050 |        0.250 |        0.190 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.580 |        0.050 |       10.810 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        1.390 |        0.290 |        4.780 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        2.800 |        0.240 |       11.440 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        2.670 |        0.250 |       10.570 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |      107.980 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.640 |        0.120 |        5.310 | ***          |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |       -0.230 |        0.140 |       -1.580 | .            |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 32, size = 1164
# Null Log-liklihood: -5360.418096
# Log-liklihood at convergence: -1620.977299
# Log-liklihood ratio: 0.697602
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.250 |        0.150 |        1.670 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.090 |        0.050 |        1.850 | *            |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.010 |            0 |       15.620 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.340 |        0.050 |       -6.580 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.420 |        0.180 |       -2.360 | **           |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.470 |        0.030 |       14.790 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        1.880 |        0.180 |       10.650 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        1.680 |        0.170 |        9.870 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        2.880 |        0.150 |       18.620 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |        0.010 |            0 |       82.220 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.390 |        0.090 |        4.420 | ***          |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.130 |        0.100 |        1.280 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 33, size = 2112
# Null Log-liklihood: -9726.119433
# Log-liklihood at convergence: -8532.475585
# Log-liklihood ratio: 0.122726
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.030 |        0.090 |        0.340 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.030 |        0.030 |        0.980 |              |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |       12.400 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.030 |        0.040 |       -0.900 |              |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.030 |        0.100 |        0.300 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.050 |        0.020 |        3.140 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.030 |        0.120 |        0.260 |              |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.030 |        0.120 |        0.260 |              |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.030 |        0.100 |        0.320 |              |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |        0.030 |            0 |     2495.480 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.030 |        0.050 |        0.640 |              |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.030 |        0.060 |        0.510 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 42, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -3512.964656
# Log-liklihood ratio: 0.682154
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.270 |        0.110 |        2.500 | **           |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.100 |        0.030 |        3.400 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        3.780 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.400 |        0.030 |      -11.920 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.110 |        0.120 |        0.900 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.510 |        0.020 |       24.550 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        2.280 |        0.110 |       20.130 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        1.480 |        0.110 |       13.040 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        2.440 |        0.110 |       22.390 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |        0.010 |            0 |       97.670 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |       -0.020 |        0.040 |       -0.620 |              |
# |      sector2 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |       -0.040 |        0.070 |       -0.660 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 44, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -3359.232658
# Log-liklihood ratio: 0.696063
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.290 |        0.100 |        2.790 | **           |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.070 |        0.030 |        2.570 | **           |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.010 |            0 |       50.830 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.060 |        0.030 |       -1.950 | *            |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.380 |        0.130 |       -2.990 | **           |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.570 |        0.020 |       24.050 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        1.090 |        0.120 |        9.400 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        2.880 |        0.100 |       30.270 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        1.030 |        0.110 |        9.280 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       19.170 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.340 |        0.070 |        4.800 | ***          |
# |      sector5 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |       -0.070 |        0.070 |       -0.930 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 45, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -3556.003175
# Log-liklihood ratio: 0.678260
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.050 |        0.090 |        0.550 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.170 |        0.030 |        6.390 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.010 |            0 |       30.590 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.130 |        0.030 |       -4.010 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.440 |        0.120 |       -3.760 | ***          |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.620 |        0.020 |       27.650 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.810 |        0.100 |        8.120 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        2.290 |        0.080 |       28.390 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.740 |        0.100 |        7.750 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       71.870 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.470 |        0.070 |        6.910 | ***          |
# |      sector5 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.050 |        0.070 |        0.770 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 48, size = 1294
# Null Log-liklihood: -5959.090221
# Log-liklihood at convergence: -3794.644653
# Log-liklihood ratio: 0.363217
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.160 |        0.110 |        1.480 | .            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.150 |        0.030 |        4.320 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.050 |            0 |      139.940 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.160 |        0.050 |       -3.540 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.160 |        0.110 |        1.450 | .            |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.280 |        0.020 |       15.890 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.160 |        0.120 |        1.300 | .            |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.150 |        0.120 |        1.280 |              |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.160 |        0.110 |        1.480 | .            |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |        0.080 |            0 |     6941.440 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.170 |        0.060 |        2.840 | **           |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.150 |        0.090 |        1.720 | *            |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 49, size = 489
# Null Log-liklihood: -2251.928221
# Log-liklihood at convergence: -796.397312
# Log-liklihood ratio: 0.646349
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.800 |        0.180 |        4.400 | ***          |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.060 |        0.060 |        1.010 |              |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.010 |            0 |       19.460 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.370 |        0.080 |       -4.620 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -1.070 |        0.200 |       -5.490 | ***          |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.620 |        0.050 |       12.860 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.730 |        0.190 |        3.840 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.430 |        0.180 |        2.370 | **           |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        1.270 |        0.170 |        7.510 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |        2.660 | **           |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.360 |        0.110 |        3.280 | ***          |
# |      sector3 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |       -0.260 |        0.150 |       -1.720 | *            |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 51, size = 1825
# Null Log-liklihood: -8404.435589
# Log-liklihood at convergence: -2485.629450
# Log-liklihood ratio: 0.704248
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |       -0.200 |        0.110 |       -1.910 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.140 |        0.030 |        4.850 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        2.810 | **           |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.390 |        0.040 |      -11.160 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.570 |        0.120 |       -4.610 | ***          |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.620 |        0.020 |       26.720 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        1.830 |        0.090 |       20.650 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.630 |        0.100 |        6.610 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.400 |        0.100 |        3.970 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       63.780 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.710 |        0.060 |       11.360 | ***          |
# |      sector6 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.140 |        0.080 |        1.810 | *            |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 52, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -9184.385625
# Log-liklihood ratio: 0.169015
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.030 |        0.090 |        0.360 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.030 |        0.020 |        1.590 | .            |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |       -7.350 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.030 |        0.020 |       -1.490 | .            |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.030 |        0.100 |        0.320 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.050 |        0.010 |        3.290 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.030 |        0.090 |        0.360 |              |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.030 |        0.090 |        0.330 |              |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |        0.030 |        0.150 |        0.210 |              |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |        0.040 |            0 |     1147.430 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.030 |        0.040 |        0.750 |              |
# ...
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -1.030 |        0.210 |       -4.980 | ***          |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.850 |        0.040 |       22.300 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |       -1.960 |        0.190 |      -10.370 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |       -2.040 |        0.180 |      -11.520 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |           -3 |        0.380 |       -7.950 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       41.080 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.560 |        0.120 |        4.830 | ***          |
# |      sector5 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.040 |        0.160 |        0.270 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 7221, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -3061.195526
# Log-liklihood ratio: 0.723029
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.110 |        0.090 |        1.140 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.250 |        0.030 |        9.930 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        2.080 | *            |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.060 |        0.030 |       -2.030 | *            |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.380 |        0.110 |       -3.430 | ***          |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.580 |        0.020 |       24.570 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.320 |        0.110 |        2.890 | **           |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        2.580 |        0.080 |       31.880 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |       -0.830 |        0.150 |       -5.580 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       38.260 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.340 |        0.060 |        5.420 | ***          |
# |      sector4 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.200 |        0.070 |        2.870 | **           |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 7222, size = 2400
# Null Log-liklihood: -11052.408446
# Log-liklihood at convergence: -2891.221363
# Log-liklihood ratio: 0.738408
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.040 |        0.100 |        0.390 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.240 |        0.030 |        8.300 | ***          |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |        0.010 |            0 |       41.930 | ***          |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.120 |        0.030 |       -3.430 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.390 |        0.120 |       -3.340 | ***          |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.500 |        0.020 |       20.040 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.590 |        0.130 |        4.670 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |            3 |        0.100 |       31.260 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |       -1.820 |        0.240 |       -7.540 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |        0.010 |            0 |       44.670 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.470 |        0.070 |        6.930 | ***          |
# |      sector4 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.120 |        0.070 |        1.590 | .            |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 7223, size = 332
# Null Log-liklihood: -1528.916502
# Log-liklihood at convergence: -584.451496
# Log-liklihood ratio: 0.617735
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |        0.450 |        0.260 |        1.700 | *            |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.160 |        0.060 |        2.740 | **           |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        2.680 | **           |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |       -0.470 |        0.080 |       -5.850 | ***          |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |       -0.300 |        0.340 |       -0.890 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.620 |        0.050 |       12.500 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |        0.670 |        0.190 |        3.480 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        0.750 |        0.170 |        4.310 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |       -0.190 |        0.200 |       -0.940 |              |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |        1.970 | *            |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.240 |        0.190 |        1.230 |              |
# |      sector5 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.020 |        0.160 |        0.150 |              |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# Estimating parameters for segment = 7224, size = 738
# Null Log-liklihood: -3398.615597
# Log-liklihood at convergence: -840.876683
# Log-liklihood ratio: 0.752583
# +--------------+--------------+--------------+--------------+--------------+
# |  Variables   | Coefficient  |    Stderr    |   T-score    | Significance |
# +==============+==============+==============+==============+==============+
# |      ln jobs |       -0.020 |        0.200 |       -0.120 |              |
# | within 30min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln avg |        0.130 |        0.060 |        2.150 | *            |
# |  nonres unit |              |              |              |              |
# |   price zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  median year |            0 |            0 |        0.670 |              |
# |        built |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |           ln |        0.100 |        0.060 |        1.550 | .            |
# |  residential |              |              |              |              |
# | unit density |              |              |              |              |
# |         zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln pop |        0.190 |        0.260 |        0.730 |              |
# | within 20min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   nonres far |        0.660 |        0.050 |       13.850 | ***          |
# +--------------+--------------+--------------+--------------+--------------+
# |       office |       -0.590 |        0.240 |       -2.450 | **           |
# +--------------+--------------+--------------+--------------+--------------+
# |    retail or |        2.190 |        0.140 |       15.150 | ***          |
# |   restaurant |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |   industrial |       -1.250 |        0.280 |       -4.490 | ***          |
# |     building |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  employees x |            0 |            0 |       -8.660 | ***          |
# |       ln non |              |              |              |              |
# |  residential |              |              |              |              |
# |    sqft zone |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |       ln emp |        0.290 |        0.150 |        1.990 | *            |
# |      sector4 |              |              |              |              |
# | within 15min |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+
# |  rail within |        0.360 |        0.130 |        2.840 | **           |
# |         mile |              |              |              |              |
# +--------------+--------------+--------------+--------------+--------------+

# %% [markdown]
# ## RESIDENTIAL REPM ESTIMATION

# %%
##Specify independent variables for each segment here.  Each variable must be represented in the variable library.  
##There must be a set of independent variables corresponding to each segment.  
ind_vars2 = ['ln_pop_within_20min','ln_units_per_acre','mean_income','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars3 = ['ln_pop_within_20min','ln_units_per_acre','mean_income','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars20 = ['ln_pop_within_20min','ln_units_per_acre','mean_income','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars24 = ['ln_pop_within_20min','ln_units_per_acre','mean_income','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]

##Apply filters
dset.d['buildings_for_estimation'] = buildings[(buildings.improvement_value>20000)*(np.in1d(buildings.building_type_id,[2,3,20,24]))]

##Esto,ate
regression_model_estimation.estimate(dset,[ind_vars2,ind_vars3,ind_vars20,ind_vars24],depvar_name = 'unit_price_residential',max_segment_size = 9000,estimation_table = 'buildings_for_estimation',
                         output_names=["drcog-coeff-reshedonic-%s.csv","DRCOG RESHEDONIC MODEL (%s)","resprice_%s","resprice"],
                         agents_groupby= ['building_type_id',])
# Out:
# Estimating hedonic for 2 with 9000 observations
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     unit_price_residential   R-squared:                       0.133
# Model:                                OLS   Adj. R-squared:                  0.131
# Method:                     Least Squares   F-statistic:                     72.59
# Date:                    Fri, 11 Apr 2014   Prob (F-statistic):          8.27e-261
# Time:                            13:28:45   Log-Likelihood:                -6419.1
# No. Observations:                    9000   AIC:                         1.288e+04
# Df Residuals:                        8980   BIC:                         1.302e+04
# Df Model:                              19
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_pop_within_20min                 -0.0692      0.023     -2.966      0.003        -0.115    -0.023
# ln_units_per_acre                   -0.2381      0.011    -22.258      0.000        -0.259    -0.217
# mean_income                       4.484e-06    2.8e-07     16.022      0.000      3.94e-06  5.03e-06
# year_built                           0.0001   4.56e-05      2.774      0.006      3.71e-05     0.000
# ln_dist_bus                          0.0118      0.008      1.561      0.119        -0.003     0.027
# ln_dist_rail                        -0.0049      0.009     -0.556      0.578        -0.022     0.012
# ln_avg_land_value_per_sqft_zone     -0.0218      0.012     -1.800      0.072        -0.046     0.002
# ln_residential_unit_density_zone     0.1791      0.013     13.325      0.000         0.153     0.205
# ln_non_residential_sqft_zone         0.0118      0.002      4.899      0.000         0.007     0.017
# allpurpose_agglosum_floor           -0.0131      0.009     -1.444      0.149        -0.031     0.005
# county8001                          -0.0153      0.023     -0.670      0.503        -0.060     0.029
# county8005                           0.0970      0.019      5.010      0.000         0.059     0.135
# county8013                           0.1461      0.038      3.825      0.000         0.071     0.221
# county8014                           0.1405      0.066      2.126      0.034         0.011     0.270
# county8019                          -0.2132      0.200     -1.066      0.286        -0.605     0.179
# county8035                           0.0679      0.038      1.804      0.071        -0.006     0.142
# county8039                         4.98e-16   1.69e-16      2.943      0.003      1.66e-16   8.3e-16
# county8047                          -0.3202      0.196     -1.635      0.102        -0.704     0.064
# county8059                          -0.0211      0.021     -1.006      0.315        -0.062     0.020
# county8123                          -0.6411      0.078     -8.238      0.000        -0.794    -0.489
# const                               11.7260      0.344     34.116      0.000        11.052    12.400
# ==============================================================================
# Omnibus:                     1911.830   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25592.294
# Skew:                          -0.638   Prob(JB):                         0.00
# Kurtosis:                      11.162   Cond. No.                     8.73e+13
# ==============================================================================
#
# The smallest eigenvalue is 5.55e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 3 with 9000 observations
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     unit_price_residential   R-squared:                       0.442
# Model:                                OLS   Adj. R-squared:                  0.441
# Method:                     Least Squares   F-statistic:                     374.3
# Date:                    Fri, 11 Apr 2014   Prob (F-statistic):               0.00
# Time:                            13:28:45   Log-Likelihood:                -6200.0
# No. Observations:                    9000   AIC:                         1.244e+04
# Df Residuals:                        8980   BIC:                         1.258e+04
# Df Model:                              19
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_pop_within_20min                 -0.1031      0.021     -4.947      0.000        -0.144    -0.062
# ln_units_per_acre                   -0.3642      0.011    -34.096      0.000        -0.385    -0.343
# mean_income                       5.053e-06   2.24e-07     22.514      0.000      4.61e-06  5.49e-06
# year_built                           0.0012      0.000     10.807      0.000         0.001     0.001
# ln_dist_bus                          0.0257      0.007      3.794      0.000         0.012     0.039
# ln_dist_rail                        -0.0809      0.009     -9.327      0.000        -0.098    -0.064
# ln_avg_land_value_per_sqft_zone      0.3364      0.012     27.821      0.000         0.313     0.360
# ln_residential_unit_density_zone    -0.0210      0.013     -1.562      0.118        -0.047     0.005
# ln_non_residential_sqft_zone         0.0073      0.002      4.007      0.000         0.004     0.011
# allpurpose_agglosum_floor            0.0650      0.009      7.311      0.000         0.048     0.082
# county8001                          -0.1182      0.026     -4.559      0.000        -0.169    -0.067
# county8005                          -0.1561      0.017     -9.346      0.000        -0.189    -0.123
# county8013                           0.3147      0.033      9.398      0.000         0.249     0.380
# county8014                           0.4361      0.046      9.386      0.000         0.345     0.527
# county8019                           0.2864      0.120      2.378      0.017         0.050     0.522
# county8035                           0.2896      0.028     10.186      0.000         0.234     0.345
# county8039                          -1.6724      0.486     -3.443      0.001        -2.625    -0.720
# county8047                        1.008e-14   3.74e-15      2.693      0.007      2.74e-15  1.74e-14
# county8059                           0.1475      0.026      5.750      0.000         0.097     0.198
# county8123                           0.7517      0.081      9.280      0.000         0.593     0.911
# const                               10.2063      0.364     28.038      0.000         9.493    10.920
# ==============================================================================
# Omnibus:                     1292.533   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9020.783
# Skew:                          -0.495   Prob(JB):                         0.00
# Kurtosis:                       7.804   Cond. No.                     9.33e+13
# ==============================================================================
#
# The smallest eigenvalue is 7.99e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 20 with 9000 observations
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     unit_price_residential   R-squared:                       0.407
# Model:                                OLS   Adj. R-squared:                  0.406
# Method:                     Least Squares   F-statistic:                     308.7
# Date:                    Fri, 11 Apr 2014   Prob (F-statistic):               0.00
# Time:                            13:28:46   Log-Likelihood:                -5731.7
# No. Observations:                    9000   AIC:                         1.151e+04
# Df Residuals:                        8979   BIC:                         1.165e+04
# Df Model:                              20
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_pop_within_20min                  0.0615      0.011      5.613      0.000         0.040     0.083
# ln_units_per_acre                   -0.2445      0.013    -19.258      0.000        -0.269    -0.220
# mean_income                       5.912e-06   2.07e-07     28.603      0.000      5.51e-06  6.32e-06
# year_built                           0.0016   9.72e-05     16.112      0.000         0.001     0.002
# ln_dist_bus                          0.0341      0.006      5.872      0.000         0.023     0.045
# ln_dist_rail                        -0.0106      0.010     -1.019      0.308        -0.031     0.010
# ln_avg_land_value_per_sqft_zone      0.3292      0.013     25.794      0.000         0.304     0.354
# ln_residential_unit_density_zone    -0.1438      0.016     -8.778      0.000        -0.176    -0.112
# ln_non_residential_sqft_zone         0.0026      0.002      1.638      0.102        -0.001     0.006
# allpurpose_agglosum_floor           -0.0230      0.009     -2.534      0.011        -0.041    -0.005
# county8001                           0.2332      0.023     10.222      0.000         0.188     0.278
# county8005                           0.3141      0.021     15.228      0.000         0.274     0.355
# county8013                           0.0512      0.029      1.739      0.082        -0.007     0.109
# county8014                           0.1535      0.040      3.838      0.000         0.075     0.232
# county8019                           0.3556      0.067      5.310      0.000         0.224     0.487
# county8035                           0.0589      0.023      2.520      0.012         0.013     0.105
# county8039                           0.1439      0.058      2.491      0.013         0.031     0.257
# county8047                           0.0200      0.074      0.270      0.787        -0.125     0.165
# county8059                           0.0578      0.020      2.953      0.003         0.019     0.096
# county8123                          -0.2437      0.041     -6.007      0.000        -0.323    -0.164
# const                                7.4733      0.249     30.036      0.000         6.986     7.961
# ==============================================================================
# Omnibus:                     1101.388   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7439.344
# Skew:                          -0.384   Prob(JB):                         0.00
# Kurtosis:                       7.387   Cond. No.                     5.38e+06
# ==============================================================================
#
# The condition number is large, 5.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Estimating hedonic for 24 with 9000 observations
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     unit_price_residential   R-squared:                       0.466
# Model:                                OLS   Adj. R-squared:                  0.464
# Method:                     Least Squares   F-statistic:                     411.8
# Date:                    Fri, 11 Apr 2014   Prob (F-statistic):               0.00
# Time:                            13:28:46   Log-Likelihood:                -4698.8
# No. Observations:                    9000   AIC:                             9438.
# Df Residuals:                        8980   BIC:                             9580.
# Df Model:                              19
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_pop_within_20min                  0.0120      0.015      0.780      0.435        -0.018     0.042
# ln_units_per_acre                   -0.1453      0.011    -13.340      0.000        -0.167    -0.124
# mean_income                       5.089e-06   2.01e-07     25.355      0.000       4.7e-06  5.48e-06
# year_built                           0.0032   9.94e-05     32.026      0.000         0.003     0.003
# ln_dist_bus                          0.0456      0.005      8.390      0.000         0.035     0.056
# ln_dist_rail                        -0.0695      0.009     -7.711      0.000        -0.087    -0.052
# ln_avg_land_value_per_sqft_zone      0.2790      0.011     25.471      0.000         0.258     0.300
# ln_residential_unit_density_zone     0.0065      0.012      0.523      0.601        -0.018     0.031
# ln_non_residential_sqft_zone         0.0230      0.002     14.034      0.000         0.020     0.026
# allpurpose_agglosum_floor           -0.0053      0.009     -0.588      0.556        -0.023     0.012
# county8001                          -0.2433      0.020    -11.978      0.000        -0.283    -0.204
# county8005                          -0.1723      0.020     -8.441      0.000        -0.212    -0.132
# county8013                          -0.3080      0.024    -13.043      0.000        -0.354    -0.262
# county8014                           0.0131      0.056      0.233      0.816        -0.097     0.123
# county8019                        -1.43e-15   1.03e-16    -13.857      0.000     -1.63e-15 -1.23e-15
# county8035                           0.0086      0.027      0.320      0.749        -0.044     0.061
# county8039                          -0.6644      0.189     -3.524      0.000        -1.034    -0.295
# county8047                           1.2786      0.104     12.311      0.000         1.075     1.482
# county8059                          -0.1260      0.018     -7.114      0.000        -0.161    -0.091
# county8123                          -0.5755      0.060     -9.580      0.000        -0.693    -0.458
# const                                4.9492      0.302     16.384      0.000         4.357     5.541
# ==============================================================================
# Omnibus:                     1292.969   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18106.133
# Skew:                          -0.156   Prob(JB):                         0.00
# Kurtosis:                       9.942   Cond. No.                     3.12e+13
# ==============================================================================
#
# The smallest eigenvalue is 8.26e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## NON-RESIDENTIAL REPM ESTIMATION

# %%
##Specify independent variables for each segment here.  Each variable must be represented in the variable library.  
##There must be a set of independent variables corresponding to each segment.  
ind_vars5 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars8 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars9 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars11 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars16 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars17 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars18 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars21 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars22 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]
ind_vars23 = ['ln_jobs_within_20min','nonres_far','year_built','ln_dist_bus','ln_dist_rail','ln_avg_land_value_per_sqft_zone','ln_residential_unit_density_zone','ln_non_residential_sqft_zone','allpurpose_agglosum_floor','county8001', 'county8005', 'county8013', 'county8014', 'county8019', 'county8035', 'county8039', 'county8047', 'county8059', 'county8123',]

##Apply filters
dset.d['buildings_for_estimation'] = buildings[(buildings.improvement_value>10000)*(np.in1d(buildings.building_type_id,[5,8,11,16,17,18,21,23,9,22]))]

##Estimate
regression_model_estimation.estimate(dset,[ind_vars5,ind_vars8,ind_vars9,ind_vars11,ind_vars16,ind_vars17,ind_vars18,ind_vars21,ind_vars22,ind_vars23],
                                     depvar_name = 'unit_price_non_residential',max_segment_size = 9000,estimation_table = 'buildings_for_estimation',
                                     output_names=["drcog-coeff-nrhedonic-%s.csv","DRCOG NRHEDONIC MODEL (%s)","nrprice_%s","nrprice"],
                                     agents_groupby= ['building_type_id',])
# Out:
# Estimating hedonic for 5 with 6565 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.168
# Model:                                    OLS   Adj. R-squared:                  0.166
# Method:                         Least Squares   F-statistic:                     73.46
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):          6.15e-245
# Time:                                13:28:47   Log-Likelihood:                -7695.6
# No. Observations:                        6565   AIC:                         1.543e+04
# Df Residuals:                            6546   BIC:                         1.556e+04
# Df Model:                                  18
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                -0.0095      0.014     -0.673      0.501        -0.037     0.018
# nonres_far                          -0.1225      0.009    -13.510      0.000        -0.140    -0.105
# year_built                          -0.0001   3.43e-05     -3.993      0.000        -0.000 -6.98e-05
# ln_dist_bus                         -0.0163      0.011     -1.484      0.138        -0.038     0.005
# ln_dist_rail                        -0.0560      0.015     -3.702      0.000        -0.086    -0.026
# ln_avg_land_value_per_sqft_zone      0.1438      0.016      8.717      0.000         0.111     0.176
# ln_residential_unit_density_zone    -0.0303      0.015     -1.974      0.048        -0.060    -0.000
# ln_non_residential_sqft_zone        -0.0772      0.010     -7.743      0.000        -0.097    -0.058
# allpurpose_agglosum_floor           -0.0070      0.004     -1.920      0.055        -0.014     0.000
# county8001                          -0.5612      0.050    -11.328      0.000        -0.658    -0.464
# county8005                          -0.3215      0.039     -8.316      0.000        -0.397    -0.246
# county8013                           0.1814      0.059      3.065      0.002         0.065     0.297
# county8014                           0.2709      0.077      3.540      0.000         0.121     0.421
# county8019                           0.7882      0.787      1.001      0.317        -0.755     2.332
# county8035                           0.1846      0.053      3.511      0.000         0.082     0.288
# county8039                        4.131e-15   2.79e-15      1.480      0.139     -1.34e-15   9.6e-15
# county8047                          -0.6835      0.153     -4.479      0.000        -0.983    -0.384
# county8059                           0.1134      0.041      2.768      0.006         0.033     0.194
# county8123                          -0.2884      0.081     -3.548      0.000        -0.448    -0.129
# const                                7.2145      0.326     22.151      0.000         6.576     7.853
# ==============================================================================
# Omnibus:                      784.136   Durbin-Watson:                   1.308
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4240.653
# Skew:                          -0.446   Prob(JB):                         0.00
# Kurtosis:                       6.835   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -7.55e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 8 with 797 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.141
# Model:                                    OLS   Adj. R-squared:                  0.121
# Method:                         Least Squares   F-statistic:                     7.112
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           4.74e-17
# Time:                                13:28:47   Log-Likelihood:                -815.85
# No. Observations:                         797   AIC:                             1670.
# Df Residuals:                             778   BIC:                             1759.
# Df Model:                                  18
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0463      0.042      1.111      0.267        -0.035     0.128
# nonres_far                           0.1006      0.030      3.373      0.001         0.042     0.159
# year_built                           0.0057      0.001      5.111      0.000         0.004     0.008
# ln_dist_bus                          0.0067      0.026      0.257      0.797        -0.045     0.058
# ln_dist_rail                         0.0788      0.054      1.467      0.143        -0.027     0.184
# ln_avg_land_value_per_sqft_zone     -0.1148      0.051     -2.270      0.023        -0.214    -0.016
# ln_residential_unit_density_zone    -0.0726      0.050     -1.462      0.144        -0.170     0.025
# ln_non_residential_sqft_zone         0.0750      0.027      2.777      0.006         0.022     0.128
# allpurpose_agglosum_floor            0.0158      0.021      0.761      0.447        -0.025     0.057
# county8001                          -0.4689      0.128     -3.651      0.000        -0.721    -0.217
# county8005                          -0.0845      0.250     -0.339      0.735        -0.574     0.405
# county8013                          -0.3038      0.156     -1.943      0.052        -0.611     0.003
# county8014                          -0.7383      0.361     -2.047      0.041        -1.446    -0.030
# county8019                           0.5974      0.716      0.834      0.405        -0.809     2.004
# county8035                          -0.1574      0.118     -1.335      0.182        -0.389     0.074
# county8039                       -3.561e-15   1.44e-15     -2.466      0.014      -6.4e-15 -7.27e-16
# county8047                          -1.2795      0.704     -1.818      0.070        -2.661     0.102
# county8059                          -0.4036      0.102     -3.966      0.000        -0.603    -0.204
# county8123                          -0.6572      0.215     -3.061      0.002        -1.079    -0.236
# const                               -9.6370      2.286     -4.216      0.000       -14.124    -5.150
# ==============================================================================
# Omnibus:                      107.262   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              905.735
# Skew:                          -0.265   Prob(JB):                    2.10e-197
# Kurtosis:                       8.196   Cond. No.                     3.06e+12
# ==============================================================================
#
# The smallest eigenvalue is 3.33e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 9 with 2279 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.079
# Model:                                    OLS   Adj. R-squared:                  0.073
# Method:                         Least Squares   F-statistic:                     11.48
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           7.73e-31
# Time:                                13:28:47   Log-Likelihood:                -3338.3
# No. Observations:                        2279   AIC:                             6713.
# Df Residuals:                            2261   BIC:                             6816.
# Df Model:                                  17
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0679      0.029      2.373      0.018         0.012     0.124
# nonres_far                          -0.0077      0.019     -0.398      0.691        -0.046     0.030
# year_built                          -0.0006      0.000     -3.462      0.001        -0.001    -0.000
# ln_dist_bus                          0.1009      0.026      3.869      0.000         0.050     0.152
# ln_dist_rail                         0.1008      0.043      2.357      0.018         0.017     0.185
# ln_avg_land_value_per_sqft_zone      0.2734      0.044      6.158      0.000         0.186     0.361
# ln_residential_unit_density_zone    -0.2417      0.054     -4.514      0.000        -0.347    -0.137
# ln_non_residential_sqft_zone         0.0896      0.025      3.612      0.000         0.041     0.138
# allpurpose_agglosum_floor           -0.0014      0.007     -0.202      0.840        -0.015     0.012
# county8001                           0.0262      0.103      0.254      0.800        -0.176     0.229
# county8005                          -0.5528      0.132     -4.191      0.000        -0.811    -0.294
# county8013                          -0.1806      0.138     -1.308      0.191        -0.451     0.090
# county8014                          -0.1573      0.157     -1.004      0.316        -0.465     0.150
# county8019                       -7.009e-16   1.02e-15     -0.688      0.491      -2.7e-15   1.3e-15
# county8035                           0.2072      0.109      1.901      0.057        -0.007     0.421
# county8039                       -1.605e-16   1.42e-16     -1.131      0.258     -4.39e-16  1.18e-16
# county8047                          -0.3137      0.630     -0.498      0.618        -1.548     0.921
# county8059                           0.4697      0.137      3.420      0.001         0.200     0.739
# county8123                          -0.5847      0.156     -3.741      0.000        -0.891    -0.278
# const                                0.6808      0.826      0.824      0.410        -0.939     2.301
# ==============================================================================
# Omnibus:                      345.217   Durbin-Watson:                   0.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3294.244
# Skew:                           0.398   Prob(JB):                         0.00
# Kurtosis:                       8.836   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -1.34e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 11 with 913 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.146
# Model:                                    OLS   Adj. R-squared:                  0.131
# Method:                         Least Squares   F-statistic:                     9.604
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           1.93e-22
# Time:                                13:28:47   Log-Likelihood:                -1006.3
# No. Observations:                         913   AIC:                             2047.
# Df Residuals:                             896   BIC:                             2129.
# Df Model:                                  16
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0210      0.025      0.847      0.397        -0.028     0.070
# nonres_far                          -0.0993      0.021     -4.808      0.000        -0.140    -0.059
# year_built                          -0.0005      0.000     -1.977      0.048        -0.001 -3.58e-06
# ln_dist_bus                         -0.0458      0.027     -1.724      0.085        -0.098     0.006
# ln_dist_rail                        -0.1260      0.043     -2.961      0.003        -0.209    -0.042
# ln_avg_land_value_per_sqft_zone      0.0630      0.036      1.772      0.077        -0.007     0.133
# ln_residential_unit_density_zone     0.2266      0.043      5.241      0.000         0.142     0.312
# ln_non_residential_sqft_zone        -0.0257      0.026     -1.003      0.316        -0.076     0.025
# allpurpose_agglosum_floor           -0.0525      0.013     -3.940      0.000        -0.079    -0.026
# county8001                          -0.3810      0.391     -0.975      0.330        -1.148     0.386
# county8005                          -0.6397      0.106     -6.061      0.000        -0.847    -0.433
# county8013                           0.0742      0.159      0.466      0.642        -0.238     0.387
# county8014                        8.636e-15   3.99e-15      2.166      0.031       8.1e-16  1.65e-14
# county8019                       -2.455e-15   1.06e-15     -2.309      0.021     -4.54e-15 -3.68e-16
# county8035                           0.0192      0.348      0.055      0.956        -0.664     0.702
# county8039                                0          0        nan        nan             0         0
# county8047                          -0.6824      0.762     -0.896      0.371        -2.178     0.813
# county8059                           0.3055      0.298      1.026      0.305        -0.279     0.890
# county8123                           0.1475      0.186      0.792      0.429        -0.218     0.513
# const                                7.7449      0.851      9.097      0.000         6.074     9.416
# ==============================================================================
# Omnibus:                      101.723   Durbin-Watson:                   1.349
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              748.156
# Skew:                           0.158   Prob(JB):                    3.47e-163
# Kurtosis:                       7.424   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -9.75e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 16 with 1314 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.271
# Model:                                    OLS   Adj. R-squared:                  0.262
# Method:                         Least Squares   F-statistic:                     28.39
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           4.34e-77
# Time:                                13:28:47   Log-Likelihood:                -2131.6
# No. Observations:                        1314   AIC:                             4299.
# Df Residuals:                            1296   BIC:                             4392.
# Df Model:                                  17
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0956      0.040      2.387      0.017         0.017     0.174
# nonres_far                          -0.3270      0.018    -18.302      0.000        -0.362    -0.292
# year_built                       -3.494e-05      0.000     -0.247      0.805        -0.000     0.000
# ln_dist_bus                         -0.1003      0.039     -2.559      0.011        -0.177    -0.023
# ln_dist_rail                         0.1818      0.055      3.317      0.001         0.074     0.289
# ln_avg_land_value_per_sqft_zone      0.2399      0.056      4.292      0.000         0.130     0.350
# ln_residential_unit_density_zone     0.1276      0.060      2.131      0.033         0.010     0.245
# ln_non_residential_sqft_zone         0.0596      0.026      2.252      0.024         0.008     0.111
# allpurpose_agglosum_floor           -0.0526      0.015     -3.495      0.000        -0.082    -0.023
# county8001                          -0.7685      0.156     -4.928      0.000        -1.074    -0.463
# county8005                          -0.2286      0.164     -1.395      0.163        -0.550     0.093
# county8013                          -0.5460      0.229     -2.385      0.017        -0.995    -0.097
# county8014                           0.5071      0.293      1.729      0.084        -0.068     1.083
# county8019                        2.095e-16   3.32e-16      0.631      0.528     -4.41e-16   8.6e-16
# county8035                           0.1979      0.154      1.287      0.198        -0.104     0.500
# county8039                       -8.628e-17   1.11e-16     -0.779      0.436     -3.04e-16  1.31e-16
# county8047                          -0.4781      0.471     -1.015      0.310        -1.402     0.446
# county8059                          -0.1204      0.144     -0.837      0.403        -0.403     0.162
# county8123                          -0.7767      0.246     -3.156      0.002        -1.259    -0.294
# const                                3.7558      1.028      3.653      0.000         1.739     5.773
# ==============================================================================
# Omnibus:                      418.298   Durbin-Watson:                   1.506
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2425.626
# Skew:                           1.353   Prob(JB):                         0.00
# Kurtosis:                       9.081   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -3.89e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 17 with 2187 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.156
# Model:                                    OLS   Adj. R-squared:                  0.149
# Method:                         Least Squares   F-statistic:                     22.32
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           1.64e-67
# Time:                                13:28:48   Log-Likelihood:                -2240.1
# No. Observations:                        2187   AIC:                             4518.
# Df Residuals:                            2168   BIC:                             4626.
# Df Model:                                  18
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0183      0.019      0.948      0.343        -0.020     0.056
# nonres_far                           0.0086      0.019      0.443      0.658        -0.029     0.047
# year_built                           0.0079      0.001     12.942      0.000         0.007     0.009
# ln_dist_bus                         -0.0413      0.015     -2.671      0.008        -0.072    -0.011
# ln_dist_rail                         0.0470      0.021      2.195      0.028         0.005     0.089
# ln_avg_land_value_per_sqft_zone      0.0278      0.026      1.078      0.281        -0.023     0.078
# ln_residential_unit_density_zone     0.0488      0.023      2.151      0.032         0.004     0.093
# ln_non_residential_sqft_zone         0.0285      0.017      1.721      0.085        -0.004     0.061
# allpurpose_agglosum_floor           -0.0115      0.006     -1.905      0.057        -0.023     0.000
# county8001                          -0.3040      0.064     -4.740      0.000        -0.430    -0.178
# county8005                          -0.1829      0.054     -3.380      0.001        -0.289    -0.077
# county8013                          -0.3028      0.082     -3.685      0.000        -0.464    -0.142
# county8014                          -0.3134      0.119     -2.628      0.009        -0.547    -0.080
# county8019                           0.3893      0.156      2.497      0.013         0.084     0.695
# county8035                           0.1463      0.073      2.017      0.044         0.004     0.289
# county8039                        2.523e-14   2.76e-15      9.133      0.000      1.98e-14  3.06e-14
# county8047                           0.0401      0.490      0.082      0.935        -0.922     1.002
# county8059                           0.1665      0.054      3.068      0.002         0.060     0.273
# county8123                          -0.0972      0.127     -0.764      0.445        -0.347     0.152
# const                              -11.9391      1.297     -9.207      0.000       -14.482    -9.396
# ==============================================================================
# Omnibus:                      321.312   Durbin-Watson:                   1.690
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              676.345
# Skew:                          -0.872   Prob(JB):                    1.36e-147
# Kurtosis:                       5.093   Cond. No.                     1.55e+12
# ==============================================================================
#
# The smallest eigenvalue is 3.55e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 18 with 9000 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.161
# Model:                                    OLS   Adj. R-squared:                  0.159
# Method:                         Least Squares   F-statistic:                     95.42
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):          9.88e-324
# Time:                                13:28:48   Log-Likelihood:                -10280.
# No. Observations:                        9000   AIC:                         2.060e+04
# Df Residuals:                            8981   BIC:                         2.073e+04
# Df Model:                                  18
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0502      0.010      5.248      0.000         0.031     0.069
# nonres_far                          -0.1650      0.008    -19.481      0.000        -0.182    -0.148
# year_built                           0.0002   9.04e-05      2.128      0.033      1.52e-05     0.000
# ln_dist_bus                         -0.0401      0.008     -4.806      0.000        -0.056    -0.024
# ln_dist_rail                         0.0502      0.013      3.821      0.000         0.024     0.076
# ln_avg_land_value_per_sqft_zone      0.1323      0.015      8.803      0.000         0.103     0.162
# ln_residential_unit_density_zone    -0.0491      0.015     -3.303      0.001        -0.078    -0.020
# ln_non_residential_sqft_zone         0.0080      0.009      0.856      0.392        -0.010     0.026
# allpurpose_agglosum_floor           -0.0231      0.004     -6.135      0.000        -0.030    -0.016
# county8001                          -0.4470      0.036    -12.577      0.000        -0.517    -0.377
# county8005                          -0.5076      0.029    -17.230      0.000        -0.565    -0.450
# county8013                          -0.2694      0.048     -5.645      0.000        -0.363    -0.176
# county8014                          -0.0173      0.068     -0.253      0.800        -0.152     0.117
# county8019                           0.3629      0.091      3.988      0.000         0.185     0.541
# county8035                           0.3236      0.040      8.050      0.000         0.245     0.402
# county8039                       -3.823e-16   9.55e-17     -4.003      0.000     -5.69e-16 -1.95e-16
# county8047                          -0.6720      0.186     -3.607      0.000        -1.037    -0.307
# county8059                          -0.0502      0.032     -1.577      0.115        -0.113     0.012
# county8123                          -0.4402      0.066     -6.699      0.000        -0.569    -0.311
# const                                4.3776      0.307     14.261      0.000         3.776     4.979
# ==============================================================================
# Omnibus:                     1060.601   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4646.241
# Skew:                          -0.510   Prob(JB):                         0.00
# Kurtosis:                       6.369   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -5.33e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 21 with 860 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.329
# Model:                                    OLS   Adj. R-squared:                  0.318
# Method:                         Least Squares   F-statistic:                     29.59
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           6.89e-64
# Time:                                13:28:48   Log-Likelihood:                -1242.6
# No. Observations:                         860   AIC:                             2515.
# Df Residuals:                             845   BIC:                             2587.
# Df Model:                                  14
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.1916      0.046      4.171      0.000         0.101     0.282
# nonres_far                          -0.1473      0.023     -6.333      0.000        -0.193    -0.102
# year_built                       -7.595e-05      0.000     -0.237      0.813        -0.001     0.001
# ln_dist_bus                         -0.1595      0.050     -3.172      0.002        -0.258    -0.061
# ln_dist_rail                         0.3345      0.118      2.845      0.005         0.104     0.565
# ln_avg_land_value_per_sqft_zone      0.2733      0.081      3.376      0.001         0.114     0.432
# ln_residential_unit_density_zone    -0.0756      0.133     -0.567      0.571        -0.337     0.186
# ln_non_residential_sqft_zone        -0.0625      0.032     -1.929      0.054        -0.126     0.001
# allpurpose_agglosum_floor           -0.1653      0.050     -3.286      0.001        -0.264    -0.067
# county8001                          -1.8573      0.778     -2.387      0.017        -3.385    -0.330
# county8005                        1.863e-15   1.31e-15      1.417      0.157     -7.17e-16  4.44e-15
# county8013                          -2.7232      0.820     -3.322      0.001        -4.332    -1.114
# county8014                        2.428e-15   1.24e-15      1.961      0.050      -2.5e-18  4.86e-15
# county8019                        -2.82e-15   1.04e-15     -2.716      0.007     -4.86e-15 -7.82e-16
# county8035                          -1.2167      0.745     -1.632      0.103        -2.680     0.246
# county8039                                0          0        nan        nan             0         0
# county8047                                0          0        nan        nan             0         0
# county8059                          -0.2774      0.762     -0.364      0.716        -1.773     1.218
# county8123                          -1.8962      0.817     -2.320      0.021        -3.500    -0.292
# const                                4.2639      1.514      2.817      0.005         1.293     7.235
# ==============================================================================
# Omnibus:                      437.080   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6996.545
# Skew:                           1.913   Prob(JB):                         0.00
# Kurtosis:                      16.439   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -3.02e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 22 with 9000 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.082
# Model:                                    OLS   Adj. R-squared:                  0.080
# Method:                         Least Squares   F-statistic:                     44.46
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):          2.78e-151
# Time:                                13:28:48   Log-Likelihood:                -9547.4
# No. Observations:                        9000   AIC:                         1.913e+04
# Df Residuals:                            8981   BIC:                         1.927e+04
# Df Model:                                  18
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0051      0.006      0.878      0.380        -0.006     0.016
# nonres_far                          -0.0647      0.007     -9.164      0.000        -0.079    -0.051
# year_built                           0.0010      0.000      6.766      0.000         0.001     0.001
# ln_dist_bus                         -0.0339      0.009     -3.898      0.000        -0.051    -0.017
# ln_dist_rail                        -0.0694      0.012     -5.738      0.000        -0.093    -0.046
# ln_avg_land_value_per_sqft_zone      0.0686      0.018      3.827      0.000         0.033     0.104
# ln_residential_unit_density_zone    -0.0355      0.016     -2.232      0.026        -0.067    -0.004
# ln_non_residential_sqft_zone         0.0514      0.009      5.994      0.000         0.035     0.068
# allpurpose_agglosum_floor           -0.0051      0.002     -2.204      0.028        -0.010    -0.001
# county8001                          -0.1305      0.030     -4.400      0.000        -0.189    -0.072
# county8005                          -0.3636      0.025    -14.479      0.000        -0.413    -0.314
# county8013                           0.0817      0.048      1.692      0.091        -0.013     0.176
# county8014                          -0.2977      0.089     -3.338      0.001        -0.472    -0.123
# county8019                           0.1794      0.085      2.100      0.036         0.012     0.347
# county8035                           0.1827      0.040      4.619      0.000         0.105     0.260
# county8039                       -1.696e-15   4.37e-16     -3.881      0.000     -2.55e-15 -8.39e-16
# county8047                          -0.1700      0.115     -1.484      0.138        -0.395     0.055
# county8059                           0.1886      0.029      6.417      0.000         0.131     0.246
# county8123                          -0.1414      0.052     -2.697      0.007        -0.244    -0.039
# const                                2.2989      0.351      6.550      0.000         1.611     2.987
# ==============================================================================
# Omnibus:                     1094.070   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9102.479
# Skew:                          -0.285   Prob(JB):                         0.00
# Kurtosis:                       7.894   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -6.66e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Estimating hedonic for 23 with 689 observations
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     unit_price_non_residential   R-squared:                       0.460
# Model:                                    OLS   Adj. R-squared:                  0.445
# Method:                         Least Squares   F-statistic:                     31.70
# Date:                        Fri, 11 Apr 2014   Prob (F-statistic):           2.16e-77
# Time:                                13:28:48   Log-Likelihood:                -796.49
# No. Observations:                         689   AIC:                             1631.
# Df Residuals:                             670   BIC:                             1717.
# Df Model:                                  18
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# ln_jobs_within_20min                 0.0568      0.025      2.241      0.025         0.007     0.107
# nonres_far                          -0.0871      0.025     -3.457      0.001        -0.137    -0.038
# year_built                           0.0002      0.000      1.121      0.263        -0.000     0.001
# ln_dist_bus                         -0.0007      0.034     -0.021      0.984        -0.066     0.065
# ln_dist_rail                         0.0450      0.038      1.181      0.238        -0.030     0.120
# ln_avg_land_value_per_sqft_zone      0.3410      0.055      6.205      0.000         0.233     0.449
# ln_residential_unit_density_zone    -0.1502      0.044     -3.408      0.001        -0.237    -0.064
# ln_non_residential_sqft_zone         0.0298      0.033      0.910      0.363        -0.035     0.094
# allpurpose_agglosum_floor           -0.0181      0.009     -2.083      0.038        -0.035    -0.001
# county8001                           0.3526      0.132      2.664      0.008         0.093     0.612
# county8005                           0.2530      0.121      2.095      0.037         0.016     0.490
# county8013                           0.6436      0.157      4.107      0.000         0.336     0.951
# county8014                           6.0973      0.328     18.607      0.000         5.454     6.741
# county8019                           0.4763      0.229      2.081      0.038         0.027     0.926
# county8035                           0.4777      0.177      2.705      0.007         0.131     0.825
# county8039                        1.217e-14   9.29e-16     13.102      0.000      1.03e-14   1.4e-14
# county8047                           0.6898      0.425      1.625      0.105        -0.144     1.523
# county8059                           0.5857      0.112      5.230      0.000         0.366     0.806
# county8123                           0.2312      0.244      0.948      0.343        -0.247     0.710
# const                                2.0115      0.818      2.459      0.014         0.405     3.618
# ==============================================================================
# Omnibus:                      174.483   Durbin-Watson:                   1.538
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              829.381
# Skew:                          -1.063   Prob(JB):                    7.98e-181
# Kurtosis:                       7.937   Cond. No.                     9.98e+11
# ==============================================================================
#
# The smallest eigenvalue is 2.66e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Coefficients to HDF5

# %%
#COEFFICIENTS TO HDF5
coeff_store_path = os.path.join(misc.data_dir(),'coeffs.h5')
coeff_store = pd.HDFStore(coeff_store_path)
coeff_store['coeffs'] = dset.coeffs
coeff_store.close()
